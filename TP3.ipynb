# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("free4ever1/instagram-fake-spammer-genuine-accounts")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'instagram-fake-spammer-genuine-accounts' dataset.
# Path to dataset files: /kaggle/input/instagram-fake-spammer-genuine-accounts

# %%
import pandas as pd

train_df = pd.read_csv("/kaggle/input/instagram-fake-spammer-genuine-accounts/train.csv")
test_df  = pd.read_csv("/kaggle/input/instagram-fake-spammer-genuine-accounts/test.csv")

train_df.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# ...
